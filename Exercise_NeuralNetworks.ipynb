# %% [markdown]
# # Exercise 4: Neural Networks
#
# This exercise is about Neural Networks and Deep Learning. We will be using [Keras](https://keras.io/) for Deep Learning. During the exercise sheet you will get a guide on how to install Keras on your machine.

# %% [markdown]
# ## Task: Hand-written Digit Recognition
#
# In this task, we analyse the famous MNIST data set for hand-written digit recognition. As the labels are only available for the training set, we will split that into a training and testing data set to build and evaluate our classifiers.
#
# - Import the MNIST data set and generate a 70/30 train-test-split.
# - Apply some basic classification algorithms and compare their performance
# - Use the `MLPClassifier` and experiment with its parameters to improve the performance
# - Use the Keras interface of tensorflow to create deep neural networks for solving the task.

# %%
# %pip install pandas
# %pip install tensorflow
# %pip install tensorflow-datasets
# %pip install matplotlib
# %pip install numpy
# %pip install scikit-learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.neural_network import MLPClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist 

# Import the data set. Use a sample of 5,000 in order to reduce the computation time.


# Sicher, ich werde das Basisskript schreiben, um diese Aufgabe zu erledigen. COVID-19-bedingte Unterbrechungen sowie menschliche Ressourcen ermöglichen es uns, nur bis zu einer rudimentären Implementierung zu kommen. Sie können es jedoch nach Belieben optimieren.
# Load MNIST dataset and split into train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 784)
X_test = X_test.reshape(X_test.shape[0], 784)
# Out:
# Requirement already satisfied: pandas in c:\python\python310\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\python\python310\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\python\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\djojo\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\djojo\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in c:\python\python310\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\python\python310\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: setuptools in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (58.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.64.1)
# Requirement already satisfied: h5py>=3.10.0 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.32.3)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\djojo\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\djojo\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.12.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: packaging in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: keras>=3.0.0 in c:\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: optree in c:\python\python310\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: namex in c:\python\python310\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: rich in c:\python\python310\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.6.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\python\python310\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\djojo\appdata\roaming\python\python310\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
#
# [notice] A new release of pip available: 22.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow-datasets in c:\python\python310\lib\site-packages (4.9.6)
# Requirement already satisfied: toml in c:\python\python310\lib\site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: pyarrow in c:\python\python310\lib\site-packages (from tensorflow-datasets) (16.1.0)
# Requirement already satisfied: simple-parsing in c:\python\python310\lib\site-packages (from tensorflow-datasets) (0.1.5)
# Requirement already satisfied: numpy in c:\python\python310\lib\site-packages (from tensorflow-datasets) (1.26.4)
# Requirement already satisfied: protobuf>=3.20 in c:\python\python310\lib\site-packages (from tensorflow-datasets) (3.20.3)
# Requirement already satisfied: click in c:\python\python310\lib\site-packages (from tensorflow-datasets) (8.1.7)
# Requirement already satisfied: tqdm in c:\python\python310\lib\site-packages (from tensorflow-datasets) (4.66.4)
# Requirement already satisfied: etils[enp,epath,epy,etree]>=1.6.0 in c:\python\python310\lib\site-packages (from tensorflow-datasets) (1.7.0)
# Requirement already satisfied: psutil in c:\users\djojo\appdata\roaming\python\python310\site-packages (from tensorflow-datasets) (6.0.0)
# Requirement already satisfied: absl-py in c:\python\python310\lib\site-packages (from tensorflow-datasets) (2.1.0)
# Requirement already satisfied: immutabledict in c:\python\python310\lib\site-packages (from tensorflow-datasets) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\python\python310\lib\site-packages (from tensorflow-datasets) (2.32.3)
# Requirement already satisfied: promise in c:\python\python310\lib\site-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: termcolor in c:\python\python310\lib\site-packages (from tensorflow-datasets) (2.4.0)
# Requirement already satisfied: wrapt in c:\python\python310\lib\site-packages (from tensorflow-datasets) (1.16.0)
# Requirement already satisfied: dm-tree in c:\python\python310\lib\site-packages (from tensorflow-datasets) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in c:\python\python310\lib\site-packages (from tensorflow-datasets) (1.15.0)
# Requirement already satisfied: typing_extensions in c:\users\djojo\appdata\roaming\python\python310\site-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets) (4.12.2)
# Requirement already satisfied: fsspec in c:\python\python310\lib\site-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets) (2024.6.0)
# Requirement already satisfied: importlib_resources in c:\python\python310\lib\site-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets) (6.4.0)
# Requirement already satisfied: zipp in c:\python\python310\lib\site-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python\python310\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python310\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (2024.6.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python310\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\python310\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (2.2.2)
# Requirement already satisfied: colorama in c:\python\python310\lib\site-packages (from click->tensorflow-datasets) (0.4.6)
# Requirement already satisfied: six in c:\users\djojo\appdata\roaming\python\python310\site-packages (from promise->tensorflow-datasets) (1.16.0)
# Requirement already satisfied: docstring-parser~=0.15 in c:\python\python310\lib\site-packages (from simple-parsing->tensorflow-datasets) (0.16)
#
# [notice] A new release of pip available: 22.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\python\python310\lib\site-packages (3.9.0)
# Requirement already satisfied: cycler>=0.10 in c:\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: numpy>=1.23 in c:\python\python310\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\python\python310\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\python310\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python\python310\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: pillow>=8 in c:\python\python310\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\djojo\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python310\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: six>=1.5 in c:\users\djojo\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\python\python310\lib\site-packages (1.26.4)
#
# [notice] A new release of pip available: 22.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\python\python310\lib\site-packages (1.5.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\python\python310\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\python\python310\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\python\python310\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\python\python310\lib\site-packages (from scikit-learn) (1.13.1)
#
# [notice] A new release of pip available: 22.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# Laden Sie die MNIST-Daten
(X_load, y_load), (X_load2, y_load2) = mnist.load_data()

# Kombinieren Sie die Trainings- und Testdaten
X = np.concatenate((X_load, X_load2))
y = np.concatenate((y_load, y_load2))

# Teilen Sie die Daten in eine 70/30 Aufteilung
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Apply and evaluate basic classification algorithms

# Logistic Regression
logReg = LogisticRegression()
logReg.fit(X_train, y_train)
predictions = logReg.predict(X_test)
print("Logistic Regression Accuracy: ",accuracy_score(y_test, predictions))

# K-Nearest Neighbors
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
predictions = knn.predict(X_test)
print("K-Nearest Neighbors Accuracy: ",accuracy_score(y_test, predictions))

# Decision Tree
DecTree = tree.DecisionTreeClassifier()
DecTree = DecTree.fit(X_train, y_train)
predictions = DecTree.predict(X_test)
print("Decision Tree Accuracy: ",accuracy_score(y_test, predictions))

# Gaussian Naive Bayes
GausNB = GaussianNB()
GausNB.fit(X_train, y_train)
predictions = GausNB.predict(X_test)
print("Gaussian Naive Bayes Accuracy: ",accuracy_score(y_test, predictions))

# Decision Tree
DecTree = DecisionTreeClassifier()
DecTree = DecTree.fit(X_train, y_train)
predictions = DecTree.predict(X_test)
print("Decision Tree Accuracy: ",accuracy_score(y_test, predictions))

# Random Forest
RandFor = RandomForestClassifier()
RandFor.fit(X_train, y_train)
predictions = RandFor.predict(X_test)
print("Random Forest Accuracy: ",accuracy_score(y_test, predictions))
# Out:
# c:\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Accuracy:  0.9196666666666666
# K-Nearest Neighbors Accuracy:  0.9684285714285714
# Decision Tree Accuracy:  0.8677619047619047
# Gaussian Naive Bayes Accuracy:  0.550952380952381
# Decision Tree Accuracy:  0.8666666666666667
# Random Forest Accuracy:  0.9654761904761905

# %%
# from sklearn.model_selection import GridSearchCV

# # Definieren Sie das Parametergitter
# param_grid = {
#     'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
#     'activation': ['tanh', 'relu'],
#     'solver': ['sgd', 'adam'],
#     'alpha': [0.0001, 0.05],
#     'learning_rate': ['constant','adaptive'],
# }

# # Erstellen Sie das Modell
# model = MLPClassifier()

# # Erstellen Sie die Grid Search
# grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

# # Führen Sie die Grid Search aus
# grid_search.fit(X_train, y_train)

# # Drucken Sie die besten Parameter aus
# print(grid_search.best_params_)

# {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %%
from sklearn.neural_network import MLPClassifier

# Apply and evaluate the MLPClassifier. Experiment with its parameters for better performance.

# MLP Classifier
mlp = MLPClassifier(activation= 'relu', alpha= 0.05, hidden_layer_sizes= (50, 100, 50), learning_rate= 'adaptive', solver= 'adam')
mlp.fit(X_train, y_train)
predictions = mlp.predict(X_test)
print("MLPClassifier Accuracy: ",accuracy_score(y_test, predictions))
# Out:
# MLPClassifier Accuracy:  0.964047619047619

# %%
# Use the Keras interface of tensorflow to solve the digit recognition task. What performance can you achieve?
# How to work with Keras in Jupyter Notebook: https://medium.com/@margaretmz/anaconda-jupyter-notebook-tensorflow-and-keras-b91f381405f8
# HINT: You have to start your Jupyter Notebook using the created environment in order to access tensorflow
# Using the the Keras-API of tensorflow: https://www.tensorflow.org/guide/keras


# Deep Neural Networks using Keras
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# convert class vectors to binary class matrices
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# create model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model
model.fit(X_train, y_train, epochs=100, batch_size=60, verbose=2)

# Evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Keras Accuracy: ", scores[1]*100)
# Out:
# c:\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 817/817 - 7s - 9ms/step - accuracy: 0.9369 - loss: 0.2058
# Epoch 2/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9752 - loss: 0.0807
# Epoch 3/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9822 - loss: 0.0539
# Epoch 4/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9865 - loss: 0.0411
# Epoch 5/100
# 817/817 - 6s - 8ms/step - accuracy: 0.9898 - loss: 0.0315
# Epoch 6/100
# 817/817 - 6s - 8ms/step - accuracy: 0.9919 - loss: 0.0237
# Epoch 7/100
# 817/817 - 6s - 8ms/step - accuracy: 0.9924 - loss: 0.0232
# Epoch 8/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9921 - loss: 0.0236
# Epoch 9/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9946 - loss: 0.0163
# Epoch 10/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9953 - loss: 0.0147
# Epoch 11/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9951 - loss: 0.0145
# Epoch 12/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9956 - loss: 0.0133
# Epoch 13/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9959 - loss: 0.0127
# Epoch 14/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9971 - loss: 0.0100
# Epoch 15/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9959 - loss: 0.0132
# Epoch 16/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9968 - loss: 0.0107
# Epoch 17/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9964 - loss: 0.0107
# Epoch 18/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9971 - loss: 0.0090
# Epoch 19/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9980 - loss: 0.0067
# Epoch 20/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9963 - loss: 0.0133
# Epoch 21/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9980 - loss: 0.0061
# Epoch 22/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9976 - loss: 0.0095
# Epoch 23/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9974 - loss: 0.0098
# Epoch 24/100
# 817/817 - 10s - 13ms/step - accuracy: 0.9977 - loss: 0.0071
# Epoch 25/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9984 - loss: 0.0051
# Epoch 26/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9963 - loss: 0.0139
# Epoch 27/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9983 - loss: 0.0062
# Epoch 28/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9980 - loss: 0.0067
# Epoch 29/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9979 - loss: 0.0081
# Epoch 30/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9979 - loss: 0.0077
# Epoch 31/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9976 - loss: 0.0113
# Epoch 32/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9986 - loss: 0.0054
# Epoch 33/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9993 - loss: 0.0024
# Epoch 34/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9979 - loss: 0.0088
# Epoch 35/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9979 - loss: 0.0091
# Epoch 36/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9982 - loss: 0.0093
# Epoch 37/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9991 - loss: 0.0039
# Epoch 38/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9977 - loss: 0.0087
# Epoch 39/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9980 - loss: 0.0086
# Epoch 40/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9985 - loss: 0.0061
# Epoch 41/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9990 - loss: 0.0031
# Epoch 42/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9984 - loss: 0.0067
# Epoch 43/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9983 - loss: 0.0065
# Epoch 44/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9985 - loss: 0.0067
# Epoch 45/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9983 - loss: 0.0078
# Epoch 46/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9983 - loss: 0.0071
# Epoch 47/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9988 - loss: 0.0056
# Epoch 48/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9995 - loss: 0.0020
# Epoch 49/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9985 - loss: 0.0079
# Epoch 50/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9980 - loss: 0.0104
# Epoch 51/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9994 - loss: 0.0030
# Epoch 52/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9987 - loss: 0.0057
# Epoch 53/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9983 - loss: 0.0079
# Epoch 54/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9991 - loss: 0.0035
# Epoch 55/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9990 - loss: 0.0043
# Epoch 56/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9986 - loss: 0.0067
# Epoch 57/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9986 - loss: 0.0072
# Epoch 58/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9997 - loss: 0.0018
# Epoch 59/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9990 - loss: 0.0054
# Epoch 60/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9988 - loss: 0.0066
# Epoch 61/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9987 - loss: 0.0061
# Epoch 62/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9987 - loss: 0.0067
# Epoch 63/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9994 - loss: 0.0020
# Epoch 64/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9992 - loss: 0.0039
# Epoch 65/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9985 - loss: 0.0076
# Epoch 66/100
# 817/817 - 6s - 8ms/step - accuracy: 0.9987 - loss: 0.0066
# Epoch 67/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9989 - loss: 0.0053
# Epoch 68/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9986 - loss: 0.0073
# Epoch 69/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9986 - loss: 0.0080
# Epoch 70/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9994 - loss: 0.0029
# Epoch 71/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9993 - loss: 0.0043
# Epoch 72/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9984 - loss: 0.0072
# Epoch 73/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9984 - loss: 0.0099
# Epoch 74/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9989 - loss: 0.0073
# Epoch 75/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9996 - loss: 0.0019
# Epoch 76/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9992 - loss: 0.0034
# Epoch 77/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9988 - loss: 0.0061
# Epoch 78/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9986 - loss: 0.0075
# Epoch 79/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9987 - loss: 0.0079
# Epoch 80/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9994 - loss: 0.0033
# Epoch 81/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9993 - loss: 0.0044
# Epoch 82/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9986 - loss: 0.0083
# Epoch 83/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9993 - loss: 0.0035
# Epoch 84/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9994 - loss: 0.0026
# Epoch 85/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9982 - loss: 0.0125
# Epoch 86/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9991 - loss: 0.0057
# Epoch 87/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9993 - loss: 0.0042
# Epoch 88/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9996 - loss: 0.0036
# Epoch 89/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9988 - loss: 0.0084
# Epoch 90/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9987 - loss: 0.0082
# Epoch 91/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9996 - loss: 0.0018
# Epoch 92/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9993 - loss: 0.0027
# Epoch 93/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9996 - loss: 0.0022
# Epoch 94/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9997 - loss: 0.0030
# Epoch 95/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9986 - loss: 0.0112
# Epoch 96/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9987 - loss: 0.0092
# Epoch 97/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9991 - loss: 0.0060
# Epoch 98/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9993 - loss: 0.0042
# Epoch 99/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9992 - loss: 0.0037
# Epoch 100/100
# 817/817 - 6s - 7ms/step - accuracy: 0.9993 - loss: 0.0070
# Keras Accuracy:  98.10952544212341

# %%
# %pip install scikeras
# from sklearn.model_selection import GridSearchCV
# from scikeras.wrappers import KerasClassifier

# # Function to create model, required for KerasClassifier
# def create_model():
# 	# create model
# 	model = Sequential()
# 	model.add(Dense(512, activation='relu', input_shape=(784,)))
# 	model.add(Dense(512, activation='relu'))
# 	model.add(Dense(10, activation='softmax'))
# 	# Compile model
# 	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# 	return model

# # create model
# model = KerasClassifier(model=create_model, verbose=0)
# # define the grid search parameters
# batch_size = [10, 20, 40, 60, 80, 100]
# epochs = [10, 50, 100]
# param_grid = dict(batch_size=batch_size, epochs=epochs)
# grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
# grid_result = grid.fit(X_train, y_train)
# # summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

#Best: 0.982327 using {'batch_size': 60, 'epochs': 100}

# %%
# save the model
model.save('mnist_model.keras')

# %%
# nehme 5 zufällige Bilder aus dem Testset und zeige sie an

# Ensure y_test contains original labels
y_test_labels = np.argmax(y_test, axis=1)  # Convert one-hot encoded labels back to original if necessary

# Predicting the classes for the test data
predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)

# Randomly selecting 5 test samples
indices = np.random.choice(range(len(X_test)), size=100)

for i, index in enumerate(indices):
    predicted_class = predicted_classes[index]
    true_class = y_test_labels[index]  # Use y_test_labels to get the true class

    plt.figure(figsize=(2, 2))
    X_test_df = pd.DataFrame(X_test)
    plt.imshow(X_test_df.iloc[index].values.reshape(28, 28), cmap='gray')
    plt.title(f"True: {true_class}, Predicted: {predicted_class}")
    plt.axis('off')
    plt.show()
# Out:
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
